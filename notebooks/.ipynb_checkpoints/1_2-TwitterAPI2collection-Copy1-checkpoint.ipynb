# %% [markdown]
# ### Simple Full Archive Search

# %%
import requests
import os
import json
import time
import datetime
import dateutil.parser
import osmnx as ox
from shapely.geometry import box

# %%
# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
file_name_base = '../data/' #enter path where you want the file saved to

bearer_token = "AAAAAAAAAAAAAAAAAAAAAI1PNgEAAAAATarF1xcbxxXdqM15JyHfxL8TLqk%3DTbEmtm5q9UZ0rDTUQa0wUerv9w3LHZAX3UM9gn3qDNvFHhTB56"#os.environ.get("BEARER_TOKEN")

search_url = "https://api.twitter.com/2/tweets/search/all"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
# query_params = {'query': '(from:twitterdev -is:retweet) OR #twitterdev','tweet.fields': 'author_id'}
query_params = {'query': f'(("george floyd" OR "elijah mcclain" OR "breonna taylor" OR (police brutality) OR blacklivesmatter OR (police violence) OR blm OR (racism police) OR (blacklives) OR (police accountability) OR "police reform" OR (defund police) OR (abolish police) OR "abolish the police" OR "police abolition" OR (police racist) OR (brutal police) OR (black lives) OR (police kill black) OR (black killed police) OR ("no justice" "no peace") OR "murdered by police" OR (police profiling) OR (police discrimination)) OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter)) has:geo point_radius:[-73.935242 40.730610 25mi]',
#                 'tweet.fields': 'author_id,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,possibly_sensitive,public_metrics,referenced_tweets,reply_settings,source,text,withheld', point_radius:[-73.935242 40.730610 25mi] "tamir rice" OR "trayvon martin" OR "elijah mcclain" OR "breonna taylor" OR "emmett till" OR "mike brown" #emmettill
                'tweet.fields': 'author_id,conversation_id,created_at,geo,entities,id,in_reply_to_user_id,referenced_tweets,public_metrics,text',
                'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
                'max_results': '10',
                'expansions': 'geo.place_id',#,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
#                 'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
                'start_time': '2020-05-20T00:00:00.00Z',
#                     'end_time': '2020-05-27T00:00:00.00Z'}
                'end_time': '2020-11-10T00:00:00.00Z'}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", search_url, headers=headers, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(search_url, headers, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))
    ts = json_response['data'][-1]['created_at']
    stamp = dateutil.parser.parse(ts).strftime('%m%d%H%M%S_%y')
    # save one file for each response
    file_name = file_name_base + stamp + '.json'
    with open(file_name , 'w') as f:
        json.dump(json_response, f)

    print("Collected", len(json_response['data']), "tweets from", json_response['data'][0]['created_at'], "to", ts)
    # update query with "next_token" from the most recent tweet to go to the next search page
    query_params['next_token'] = json_response['meta']['next_token']
    
#     return json_response

# if __name__ == "__main__":
# #     test = main()
#     main()

    
if __name__ == "__main__":
    while(True):
        try:
            main()  
        except:
            time.sleep(10)
            print("program restart")

# %% [markdown]
# ### Full archive search with more detailed geo-information

# %%
# Creating an H3 Hexagon Grid
import pandas as pd
import os
import numpy as np
import itertools
from pprint import pprint
from h3 import h3
import folium
import shapely.geometry
import geopandas as gpd
import requests, zipfile, io
from datetime import datetime

def create_hexgrid(polygon, hex_res, geometry_col='geometry', map_zoom=12, buffer=0.000,
                   stroke_weight=0.5, stroke_color='blue', plot=True):
    """ Takes in a geopandas geodataframe, the desired resolution, the specified geometry column
        and some map parameters to create a hexagon grid (and potentially plot the hexgrid
    """
    centroid = list(polygon.centroid.values[0].coords)[0]
    fol_map = folium.Map(location=[centroid[1], centroid[0]], zoom_start=map_zoom,
                         tiles='cartodbpositron')

    # Explode multipolygon into individual polygons
    exploded = polygon.explode().reset_index(drop=True)

    # Master lists for geodataframe
    hexagon_polygon_list = []
    hexagon_geohash_list = []

    # For each exploded polygon
    for poly in exploded[geometry_col].values:

        # Reverse coords for original polygon
        coords = list(poly.exterior.coords)
        reversed_coords = []
        for i in coords:
            reversed_coords.append([i[1], i[0]])

        # Reverse coords for buffered polygon
        buffer_poly = poly.buffer(buffer)
        buffer_coords = list(buffer_poly.exterior.coords)
        reversed_buffer_coords = []
        for i in buffer_coords:
            reversed_buffer_coords.append([i[1], i[0]])

        # Format input to the way H3 expects it
        aoi_input = {'type': 'Polygon', 'coordinates': [reversed_buffer_coords]}

        # Add polygon outline to map
        outline = reversed_coords
        outline.append(outline[0])
        outline = folium.PolyLine(locations=outline, weight=1, color='black')
        fol_map.add_child(outline)

        # Generate list geohashes filling the AOI
        geohashes = list(h3.polyfill(aoi_input, hex_res))

        # Generate hexagon polylines for Folium
        polylines = []
        lat = []
        lng = []
        for geohash in geohashes:
            polygons = h3.h3_set_to_multi_polygon([geohash], geo_json=False)
            outlines = [loop for polygon in polygons for loop in polygon]
            polyline = [outline + [outline[0]] for outline in outlines][0]
            lat.extend(map(lambda x: x[0], polyline))
            lng.extend(map(lambda x: x[1], polyline))
            polylines.append(polyline)
            hexagon_geohash_list.append(geohash)

        # Add the hexagon polylines to Folium map
        for polyline in polylines:
            my_polyline = folium.PolyLine(locations=polyline, weight=stroke_weight,
                                          color=stroke_color)
            fol_map.add_child(my_polyline)

        # Generate hexagon polygons for Shapely
        for geohash in geohashes:
            polygons = h3.h3_set_to_multi_polygon([geohash], geo_json=True)
            outlines = [loop for polygon in polygons for loop in polygon]
            polyline_geojson = [outline + [outline[0]] for outline in outlines][0]
            hexagon_polygon_list.append(shapely.geometry.Polygon(polyline_geojson))

    if plot:
        display(fol_map)

    # Create a geodataframe containing the hexagon geometries and hashes
    hexgrid_gdf = gpd.GeoDataFrame()
    hexgrid_gdf['geometry'] = hexagon_polygon_list
    id_col_name = 'hex_id_' + str(hex_res)
    hexgrid_gdf[id_col_name] = hexagon_geohash_list
    hexgrid_gdf.crs = {'init' :'epsg:4326'}

    # Drop duplicate geometries
    geoms_wkb = hexgrid_gdf["geometry"].apply(lambda geom: geom.wkb)
    hexgrid_gdf = hexgrid_gdf.loc[geoms_wkb.drop_duplicates().index]

    return hexgrid_gdf

# %%
import osmnx as ox
from shapely.geometry import box
# example of NYC
city = "Colombia" #"United States"
# city = "Chicago"
city_AREA = ox.gdf_from_place(city)

# city_AREA = gpd.GeoDataFrame(ox.gdf_from_place(city), geometry=[box(*ox.gdf_from_place(city).bounds.values[0])])
res = 4 #https://github.com/uber/h3/blob/master/docs/core-library/restable.md
grid_city = create_hexgrid(city_AREA, hex_res = res, geometry_col='geometry', map_zoom=11, buffer=0.000,
                        stroke_weight=0.5, stroke_color='blue', plot=False)

# %%
grid_city.to_file(f"../data/raw/grids/{city}_{res}res_grid.geojson", driver="GeoJSON")

# %%
# for index, row in grid_city.iloc[:10,:].iterrows():
#     # print(row.geometry.centroid.x, row.geometry.centroid.y)

#     radius = "17mi"
#     # change point radius query for each area
#     geo_query = f"{row.geometry.centroid.x} {row.geometry.centroid.y} {radius}"
    
#     hex_id = row[f"hex_id_{res}"]
    
#     query_params = {'query': f'(("george floyd" OR "elijah mcclain" OR "breonna taylor" OR (police brutality) OR blacklivesmatter OR (police violence) OR blm OR (racism police) OR (blacklives) OR (police accountability) OR "police reform" OR (defund police) OR (abolish police) OR "abolish the police" OR "police abolition" OR (police racist) OR (brutal police) OR (black lives) OR (police kill black) OR (black killed police) OR ("no justice" "no peace") OR "murdered by police" OR (police profiling) OR (police discrimination)) OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter)) has:geo point_radius:[{geo_query}]',
#                     'tweet.fields': 'author_id,conversation_id,created_at,geo,entities,id,in_reply_to_user_id,referenced_tweets,public_metrics,text',
#                     'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
#                     'max_results': '500',
#                     'expansions': 'geo.place_id,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
#                     'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
#                     'start_time': '2020-05-20T00:00:00.00Z',
#                     'end_time': '2020-11-10T00:00:00.00Z'}
#     print(query_params)
#     print("_____")

# %% [markdown]
# ### Loop through Hex-Grid

# %% [markdown]
# ####  (US Wide Collection)

# %%
# %%time
# hex_NYC.geometry[100].centroid.y
import requests
import os
import json
import time
import datetime
import dateutil.parser

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
# file_name_base = '../data/' #enter path where you want the file saved to
file_name_base = 'E:/police_brutality_tweets/full_history_geo/'

# bearer_token = "AAAAAAAAAAAAAAAAAAAAAI1PNgEAAAAATarF1xcbxxXdqM15JyHfxL8TLqk%3DTbEmtm5q9UZ0rDTUQa0wUerv9w3LHZAX3UM9gn3qDNvFHhTB56"#os.environ.get("BEARER_TOKEN")

bearer_token = "AAAAAAAAAAAAAAAAAAAAAMiRMwEAAAAAajrtTBAkLc2mbCdBNTt63PARNqg%3D8o4ZQfDKVvKX0JS1QqHxCb0ZweiOx8dFLt0BQKJJctzwTihPi5"#os.environ.get("BEARER_TOKEN")

search_url = "https://api.twitter.com/2/tweets/search/all"

# city = "test"
# set search radius in miles
# radius = "0.76mi"
# radius = "2.15mi"
radius = "17mi"
# iterate through each hexagon's centroid
for index, row in grid_city.iloc[1285:,:].iterrows():
    # print(row.geometry.centroid.x, row.geometry.centroid.y)

    # change point radius query for each area
    geo_query = f"{row.geometry.centroid.x} {row.geometry.centroid.y} {radius}"
    
    hex_id = row[f"hex_id_{res}"]
    print("Searching tweets within hexagon", hex_id, ": ", index, "out of", str(len(grid_city)), "hexagons scanned for tweets!")
    # print(geo_query)
    # update query at each iteration
#     query_params = {'query': f'(("george floyd" OR "tamir rice" OR "trayvon martin" OR "elijah mcclain" OR "breonna taylor" OR "breonna" OR "emmett till" OR "mike brown" OR "eric garner" OR "police brutality" OR "black lives matter" OR blacklivesmatter OR "police violence" OR blm OR racism OR "black lives" OR "police accountability" OR "police reform" OR "defund the police" OR "defund police" OR "abolish police" OR "abolish the police" OR "police abolition") OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #blacktranslivesmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter OR #justiceforbre)) has:geo point_radius:[{geo_query}]',
    query_params = {'query': f'(("george floyd" OR "elijah mcclain" OR "breonna taylor" OR (police brutality) OR blacklivesmatter OR (police violence) OR blm OR (racism police) OR (blacklives) OR (police accountability) OR "police reform" OR (defund police) OR (abolish police) OR "abolish the police" OR "police abolition" OR (police racist) OR (brutal police) OR (black lives) OR (police kill black) OR (black killed police) OR ("no justice" "no peace") OR "murdered by police" OR (police profiling) OR (police discrimination)) OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #blacklivesstillmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter)) has:geo point_radius:[{geo_query}]',
                    'tweet.fields': 'author_id,conversation_id,created_at,geo,entities,id,in_reply_to_user_id,referenced_tweets,public_metrics,text',
                    'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
                    'max_results': '500',
                    'expansions': 'geo.place_id,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
                    'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
                    'start_time': '2020-05-20T00:00:00.00Z',
                    'end_time': '2020-11-10T00:00:00.00Z'}


    def create_headers(bearer_token):
        headers = {"Authorization": "Bearer {}".format(bearer_token)}
        return headers


    def connect_to_endpoint(url, headers, params):
        response = requests.request("GET", search_url, headers=headers, params=params)
        print(response.status_code)
        if response.status_code != 200:
            raise Exception(response.status_code, response.text)
        return response.json()


    def main():
        headers = create_headers(bearer_token)
        json_response = connect_to_endpoint(search_url, headers, query_params)
#         print(json.dumps(json_response, indent=4, sort_keys=True))
        
        try:
            ts = json_response['data'][-1]['created_at']
            stamp = dateutil.parser.parse(ts).strftime('%m%d%H%M%S_%y')
            # save one file for each response
            file_name = file_name_base + str(res) + 'res' + '/' + city.replace(" ", "") + "_" + hex_id + "_" + str(res) + "res" + "_" + stamp + '.json'
#             print(file_name)

            with open(file_name , 'w') as f:
#                 json.dump(json_response['data'], f)
                json.dump(json_response, f)

            print("Collected", len(json_response['data']), "tweets from", json_response['data'][0]['created_at'], 
                  "to", ts, "inside hexagon", hex_id)
            # update query with "next_token" from the most recent tweet to go to the next search page
            query_params['next_token'] = json_response['meta']['next_token']
            
        except KeyError:
            print("Response returned no data")
        
        return json_response

    #     return json_response

#     if __name__ == "__main__":
#     #     test = main()
#         main()


    if __name__ == "__main__":
        while(True):
            try:
                response = main()  
                if ("next_token" not in response['meta']) or (response['meta']["result_count"] == 0):
                    print("No more data to collect for hexagon", hex_id)
                    break
            except:
                print("Too many requests, sleeping...")
                time.sleep(20)
                print("Program restart!")

# %% [markdown]
# ####  (Colombia Wide Collection)

# %%
# %%time
# hex_NYC.geometry[100].centroid.y
import requests
import os
import json
import time
import datetime
import dateutil.parser

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
file_name_base = '../data/raw/full_archive/colombia' #enter path where you want the file saved to
# file_name_base = 'E:/police_brutality_tweets/full_history_geo/'

bearer_token = "AAAAAAAAAAAAAAAAAAAAAI1PNgEAAAAATarF1xcbxxXdqM15JyHfxL8TLqk%3DTbEmtm5q9UZ0rDTUQa0wUerv9w3LHZAX3UM9gn3qDNvFHhTB56"#os.environ.get("BEARER_TOKEN")

# bearer_token = "AAAAAAAAAAAAAAAAAAAAAMiRMwEAAAAAajrtTBAkLc2mbCdBNTt63PARNqg%3D8o4ZQfDKVvKX0JS1QqHxCb0ZweiOx8dFLt0BQKJJctzwTihPi5"#os.environ.get("BEARER_TOKEN")

search_url = "https://api.twitter.com/2/tweets/search/all"

# city = "test"
# set search radius in miles
# radius = "0.76mi"
# radius = "2.15mi"
radius = "17mi"
# iterate through each hexagon's centroid
for index, row in grid_city.iterrows():
    # print(row.geometry.centroid.x, row.geometry.centroid.y)

    # change point radius query for each area
    geo_query = f"{row.geometry.centroid.x} {row.geometry.centroid.y} {radius}"
    
    hex_id = row[f"hex_id_{res}"]
    print("Searching tweets within hexagon", hex_id, ": ", index, "out of", str(len(grid_city)), "hexagons scanned for tweets!")
    # print(geo_query)
    # update query at each iteration
#     query_params = {'query': f'(("george floyd" OR "tamir rice" OR "trayvon martin" OR "elijah mcclain" OR "breonna taylor" OR "breonna" OR "emmett till" OR "mike brown" OR "eric garner" OR "police brutality" OR "black lives matter" OR blacklivesmatter OR "police violence" OR blm OR racism OR "black lives" OR "police accountability" OR "police reform" OR "defund the police" OR "defund police" OR "abolish police" OR "abolish the police" OR "police abolition") OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #blacktranslivesmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter OR #justiceforbre)) has:geo point_radius:[{geo_query}]',
#     query_params = {'query': f'((paronacional OR resistencia OR sangre OR lucha OR luchar OR matando OR matar OR protesta OR "human rights" OR "police brutality" OR dictatura OR paramilitaries OR ("human rights" violation) OR agresiones OR manifestaciones OR heridos OR "derechos humanos" OR (police abuse) OR ESMAD OR abusos OR (ataques prensa) OR dictaduras OR (police oppression) OR manifestantes OR (derecho protesta) OR "primera línea" OR duque OR DDHH OR crisis OR repression OR democracia OR "primera línea" OR "nos están matando") OR (#LucasVillaVásquez OR #colombia OR #humanrights OR #SOSPereira OR #nicolasguerrero OR #dilancruz OR #LucasVilla OR #Disparos OR #Estudiante OR #LucasNoMurioALucasLoMataron OR #SOSColombiaNosEstanMatando OR #Barbosa OR #ColombiaSOSDDHH OR #PetroNoCaeEnLaTrampa OR #LUCAS OR #LucasFueAsesinado OR #LucasVive OR #LucasRepresenta OR #lucasestavivo OR #YoPido OR #LucasVillaAsesinadoPorElEstado OR #ColombiaSOSDDHH OR #ColombiaSinPresidente OR #ColombiaResiste OR #SOSColombiaNoDuerme OR #SOSColombiaDDHH OR #ColombiaSOS OR #DDHHinternacional OR #lucasnomereciaesto OR #LucasSomosTodos OR #PereiraResisteConAmor OR #Pereira OR #NosEstanMatando OR #viaductopereira OR #Barbosa OR #PetroNoCaeEnLaTrampa OR #SOSColombiaNoDuerme OR #CensuraColombia OR #ColombiaResiste OR #CaliEnPeligro OR #ColombiaEnAlertaRoja OR #CALIESTACENSURADO OR #YoPido OR #SeProtestaPor OR #ColombianLivesMatter OR #Colombian OR #SOSCali OR #SOSCaliDDHH OR #UribeGenocida OR #FuerzaCOLOMBIA OR #Prayforcolombia OR #ColombiaEnDictadura OR #fuckuribe OR #fuckduque OR #ColombiaRedAlert OR #ElParoNoPara OR #DuqueResign OR #paronacional OR #HumanRightsViolations OR #SOSCOLOMBIAENDICTADURA OR #RepresiónOficial OR #SOSMedellinDDHH OR #JusticiaParaSamuel OR #ddhh OR #DelegacioCatalunyaColombia OR #MisiónSOSColombia OR #MalaNotaPara OR #primeralínea OR #ProtestasEnColombia OR #ESMAD)) has:geo point_radius:[{geo_query}]',
    query_params = {'query': f'((paronacional OR soscolombia OR colombiasos OR NosEstanMatando OR resistencia OR sangre OR lucha OR luchar OR matando OR matar OR protesta OR "human rights" OR "police brutality" OR LucasVilla OR dictadura OR paramilitaries OR ("human rights" violation) OR agresiones OR manifestaciones OR heridos OR "derechos humanos" OR polícia OR ESMAD OR abusos OR (ataques prensa) OR dictaduras OR (police oppression) OR manifestantes OR (derecho protesta) OR "primera línea" OR duque OR DDHH OR crisis OR repression OR "primera línea" OR "nos están matando") OR (#humanrights OR #SOSPereira OR #Disparos OR #Estudiante OR #ColombiaSOSDDHH OR #YoPido OR #ColombiaResiste OR #ColombiaSOS OR #DDHHinternacional OR #NosEstanMatando OR #SOSColombiaNoDuerme OR #ColombiaResiste OR #ColombiaEnAlertaRoja OR #SeProtestaPor OR #ColombianLivesMatter OR #FuerzaCOLOMBIA OR #ColombiaEnDictadura OR #ColombiaRedAlert OR #ElParoNoPara OR #DuqueResign)) has:geo point_radius:[{geo_query}]',
                    'tweet.fields': 'author_id,conversation_id,created_at,geo,entities,id,in_reply_to_user_id,referenced_tweets,public_metrics,text',
                    'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
                    'max_results': '500',
                    'expansions': 'geo.place_id,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
                    'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
                    'start_time': '2021-04-27T00:00:00.00Z',
                    'end_time': '2021-07-05T00:00:00.00Z'}


    def create_headers(bearer_token):
        headers = {"Authorization": "Bearer {}".format(bearer_token)}
        return headers


    def connect_to_endpoint(url, headers, params):
        response = requests.request("GET", search_url, headers=headers, params=params)
        print(response.status_code)
        if response.status_code != 200:
            raise Exception(response.status_code, response.text)
        return response.json()


    def main():
        headers = create_headers(bearer_token)
        json_response = connect_to_endpoint(search_url, headers, query_params)
#         print(json.dumps(json_response, indent=4, sort_keys=True))
        
        try:
            ts = json_response['data'][-1]['created_at']
            stamp = dateutil.parser.parse(ts).strftime('%m%d%H%M%S_%y')
            # save one file for each response
            file_name = file_name_base + str(res) + 'res' + '/' + city.replace(" ", "") + "_" + hex_id + "_" + str(res) + "res" + "_" + stamp + '.json'
#             print(file_name)

            with open(file_name , 'w') as f:
#                 json.dump(json_response['data'], f)
                json.dump(json_response, f)

            print("Collected", len(json_response['data']), "tweets from", json_response['data'][0]['created_at'], 
                  "to", ts, "inside hexagon", hex_id)
            # update query with "next_token" from the most recent tweet to go to the next search page
            query_params['next_token'] = json_response['meta']['next_token']
            
        except KeyError:
            print("Response returned no data")
        
        return json_response

    #     return json_response

#     if __name__ == "__main__":
#     #     test = main()
#         main()


    if __name__ == "__main__":
        while(True):
            try:
                response = main()  
                if ("next_token" not in response['meta']) or (response['meta']["result_count"] == 0):
                    print("No more data to collect for hexagon", hex_id)
                    break
            except:
                print("Too many requests, sleeping...")
                time.sleep(20)
                print("Program restart!")
# Out:
# Searching tweets within hexagon 846783dffffffff :  0 out of 678 hexagons scanned for tweets!
# 200
# Collected 78 tweets from 2021-07-03T19:42:53.000Z to 2021-04-28T17:40:30.000Z inside hexagon 846783dffffffff
# Response returned no data
# No more data to collect for hexagon 846783dffffffff
# Searching tweets within hexagon 8467835ffffffff :  1 out of 678 hexagons scanned for tweets!
# 200
# Collected 78 tweets from 2021-07-03T19:42:53.000Z to 2021-04-28T17:40:30.000Z inside hexagon 8467835ffffffff
# Response returned no data
# No more data to collect for hexagon 8467835ffffffff
# Searching tweets within hexagon 8467831ffffffff :  2 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8467831ffffffff
# Searching tweets within hexagon 84679cbffffffff :  3 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 84679cbffffffff
# Searching tweets within hexagon 846780dffffffff :  4 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 846780dffffffff
# Searching tweets within hexagon 8467805ffffffff :  5 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 3 tweets from 2021-06-12T15:12:52.000Z to 2021-05-29T00:45:05.000Z inside hexagon 8467805ffffffff
# Response returned no data
# No more data to collect for hexagon 8467805ffffffff
# Searching tweets within hexagon 8467801ffffffff :  6 out of 678 hexagons scanned for tweets!
# 200
# Collected 3 tweets from 2021-06-12T15:12:52.000Z to 2021-05-29T00:45:05.000Z inside hexagon 8467801ffffffff
# Response returned no data
# No more data to collect for hexagon 8467801ffffffff
# Searching tweets within hexagon 8467841ffffffff :  7 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467841ffffffff
# Searching tweets within hexagon 8467847ffffffff :  8 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467847ffffffff
# Searching tweets within hexagon 8467a37ffffffff :  9 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467a37ffffffff
# Searching tweets within hexagon 8467851ffffffff :  10 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467851ffffffff
# Searching tweets within hexagon 8467853ffffffff :  11 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467853ffffffff
# Searching tweets within hexagon 8467a09ffffffff :  12 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467a09ffffffff
# Searching tweets within hexagon 8466547ffffffff :  13 out of 678 hexagons scanned for tweets!
# 200
# Collected 47 tweets from 2021-06-26T16:17:05.000Z to 2021-04-28T16:09:35.000Z inside hexagon 8466547ffffffff
# Response returned no data
# No more data to collect for hexagon 8466547ffffffff
# Searching tweets within hexagon 8466f01ffffffff :  14 out of 678 hexagons scanned for tweets!
# 200
# Collected 445 tweets from 2021-07-04T13:57:37.000Z to 2021-05-20T19:09:18.000Z inside hexagon 8466f01ffffffff
# 200
# Collected 499 tweets from 2021-05-20T18:56:09.000Z to 2021-05-06T04:39:07.000Z inside hexagon 8466f01ffffffff
# 200
# Collected 489 tweets from 2021-05-06T04:37:46.000Z to 2021-04-29T19:26:09.000Z inside hexagon 8466f01ffffffff
# 200
# Collected 34 tweets from 2021-04-29T18:11:41.000Z to 2021-04-27T03:02:12.000Z inside hexagon 8466f01ffffffff
# Response returned no data
# No more data to collect for hexagon 8466f01ffffffff
# Searching tweets within hexagon 8467561ffffffff :  15 out of 678 hexagons scanned for tweets!
# 200
# Collected 13 tweets from 2021-06-30T19:18:41.000Z to 2021-04-28T19:30:33.000Z inside hexagon 8467561ffffffff
# Response returned no data
# No more data to collect for hexagon 8467561ffffffff
# Searching tweets within hexagon 8466095ffffffff :  16 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 229 tweets from 2021-07-01T02:06:29.000Z to 2021-04-27T21:34:09.000Z inside hexagon 8466095ffffffff
# Response returned no data
# No more data to collect for hexagon 8466095ffffffff
# Searching tweets within hexagon 84665e3ffffffff :  17 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 84665e3ffffffff
# Searching tweets within hexagon 8466469ffffffff :  18 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466469ffffffff
# Searching tweets within hexagon 848a451ffffffff :  19 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 71 tweets from 2021-07-03T23:34:34.000Z to 2021-04-28T05:15:18.000Z inside hexagon 848a451ffffffff
# Response returned no data
# No more data to collect for hexagon 848a451ffffffff
# Searching tweets within hexagon 8466d19ffffffff :  20 out of 678 hexagons scanned for tweets!
# 200
# Collected 497 tweets from 2021-07-04T16:24:36.000Z to 2021-05-22T21:44:04.000Z inside hexagon 8466d19ffffffff
# 200
# Collected 499 tweets from 2021-05-22T19:25:32.000Z to 2021-05-07T09:26:47.000Z inside hexagon 8466d19ffffffff
# 200
# Collected 499 tweets from 2021-05-07T08:54:52.000Z to 2021-05-02T15:45:42.000Z inside hexagon 8466d19ffffffff
# 200
# Collected 241 tweets from 2021-05-02T14:59:39.000Z to 2021-04-27T11:55:39.000Z inside hexagon 8466d19ffffffff
# Response returned no data
# No more data to collect for hexagon 8466d19ffffffff
# Searching tweets within hexagon 848a4b1ffffffff :  21 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4b1ffffffff
# Searching tweets within hexagon 8466f31ffffffff :  22 out of 678 hexagons scanned for tweets!
# 200
# Collected 500 tweets from 2021-07-03T17:25:41.000Z to 2021-05-18T22:12:44.000Z inside hexagon 8466f31ffffffff
# 200
# Collected 500 tweets from 2021-05-18T22:00:24.000Z to 2021-05-05T01:46:08.000Z inside hexagon 8466f31ffffffff
# 200
# Collected 206 tweets from 2021-05-05T01:42:04.000Z to 2021-04-28T21:28:03.000Z inside hexagon 8466f31ffffffff
# Response returned no data
# No more data to collect for hexagon 8466f31ffffffff
# Searching tweets within hexagon 848a4e3ffffffff :  23 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4e3ffffffff
# Searching tweets within hexagon 848a49bffffffff :  24 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 848a49bffffffff
# Searching tweets within hexagon 84660a9ffffffff :  25 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 371 tweets from 2021-07-01T04:16:33.000Z to 2021-04-28T01:32:49.000Z inside hexagon 84660a9ffffffff
# Response returned no data
# No more data to collect for hexagon 84660a9ffffffff
# Searching tweets within hexagon 846646bffffffff :  26 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 846646bffffffff
# Searching tweets within hexagon 8466ebbffffffff :  27 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466ebbffffffff
# Searching tweets within hexagon 84661d3ffffffff :  28 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 209 tweets from 2021-07-04T01:41:18.000Z to 2021-06-01T18:01:52.000Z inside hexagon 84661d3ffffffff
# 200
# Collected 497 tweets from 2021-06-01T15:41:50.000Z to 2021-05-07T15:25:55.000Z inside hexagon 84661d3ffffffff
# 200
# Collected 495 tweets from 2021-05-07T14:49:07.000Z to 2021-04-30T15:59:01.000Z inside hexagon 84661d3ffffffff
# 200
# Collected 47 tweets from 2021-04-30T15:37:31.000Z to 2021-04-27T21:10:53.000Z inside hexagon 84661d3ffffffff
# Response returned no data
# No more data to collect for hexagon 84661d3ffffffff
# Searching tweets within hexagon 8466e47ffffffff :  29 out of 678 hexagons scanned for tweets!
# 200
# Collected 500 tweets from 2021-07-04T23:39:26.000Z to 2021-06-23T04:36:42.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 500 tweets from 2021-06-23T04:34:03.000Z to 2021-06-11T13:07:56.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 497 tweets from 2021-06-11T12:50:43.000Z to 2021-06-05T02:42:55.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 496 tweets from 2021-06-05T02:41:43.000Z to 2021-05-30T13:25:45.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 498 tweets from 2021-05-30T13:19:34.000Z to 2021-05-27T18:06:19.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 499 tweets from 2021-05-27T18:04:03.000Z to 2021-05-24T00:13:29.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 500 tweets from 2021-05-24T00:02:23.000Z to 2021-05-20T13:47:18.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 495 tweets from 2021-05-20T13:47:08.000Z to 2021-05-17T04:29:08.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 498 tweets from 2021-05-17T03:40:26.000Z to 2021-05-13T14:57:59.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 500 tweets from 2021-05-13T14:54:50.000Z to 2021-05-11T00:38:44.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 495 tweets from 2021-05-11T00:29:45.000Z to 2021-05-08T21:56:26.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 495 tweets from 2021-05-08T21:56:04.000Z to 2021-05-07T02:17:49.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 495 tweets from 2021-05-07T02:17:39.000Z to 2021-05-06T04:49:20.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 496 tweets from 2021-05-06T04:47:47.000Z to 2021-05-05T15:10:58.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 497 tweets from 2021-05-05T15:06:57.000Z to 2021-05-04T22:23:43.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 497 tweets from 2021-05-04T22:23:10.000Z to 2021-05-04T06:55:07.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 500 tweets from 2021-05-04T06:51:32.000Z to 2021-05-03T14:33:18.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 497 tweets from 2021-05-03T14:33:10.000Z to 2021-05-02T07:07:10.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 499 tweets from 2021-05-02T07:05:14.000Z to 2021-05-01T03:02:28.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 497 tweets from 2021-05-01T02:46:43.000Z to 2021-04-28T18:32:20.000Z inside hexagon 8466e47ffffffff
# 200
# Collected 188 tweets from 2021-04-28T18:27:05.000Z to 2021-04-27T00:10:18.000Z inside hexagon 8466e47ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e47ffffffff
# Searching tweets within hexagon 8466e21ffffffff :  30 out of 678 hexagons scanned for tweets!
# 200
# Collected 43 tweets from 2021-06-30T19:53:38.000Z to 2021-04-28T02:42:53.000Z inside hexagon 8466e21ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e21ffffffff
# Searching tweets within hexagon 8466731ffffffff :  31 out of 678 hexagons scanned for tweets!
# 200
# Collected 25 tweets from 2021-06-17T01:18:11.000Z to 2021-04-29T10:57:13.000Z inside hexagon 8466731ffffffff
# Response returned no data
# No more data to collect for hexagon 8466731ffffffff
# Searching tweets within hexagon 848a4a9ffffffff :  32 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4a9ffffffff
# Searching tweets within hexagon 8466c67ffffffff :  33 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 147 tweets from 2021-07-02T10:57:07.000Z to 2021-04-28T14:05:04.000Z inside hexagon 8466c67ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c67ffffffff
# Searching tweets within hexagon 8466529ffffffff :  34 out of 678 hexagons scanned for tweets!
# 200
# Collected 102 tweets from 2021-07-04T20:14:46.000Z to 2021-04-28T16:20:01.000Z inside hexagon 8466529ffffffff
# Response returned no data
# No more data to collect for hexagon 8466529ffffffff
# Searching tweets within hexagon 8466525ffffffff :  35 out of 678 hexagons scanned for tweets!
# 200
# Collected 27 tweets from 2021-07-04T20:14:46.000Z to 2021-04-28T16:20:01.000Z inside hexagon 8466525ffffffff
# Response returned no data
# No more data to collect for hexagon 8466525ffffffff
# Searching tweets within hexagon 8466e69ffffffff :  36 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 499 tweets from 2021-07-04T21:40:12.000Z to 2021-05-26T18:56:15.000Z inside hexagon 8466e69ffffffff
# 200
# Collected 499 tweets from 2021-05-26T18:53:34.000Z to 2021-05-11T16:15:54.000Z inside hexagon 8466e69ffffffff
# 200
# Collected 496 tweets from 2021-05-11T15:49:28.000Z to 2021-05-04T19:13:47.000Z inside hexagon 8466e69ffffffff
# 200
# Collected 495 tweets from 2021-05-04T19:01:32.000Z to 2021-05-01T20:49:10.000Z inside hexagon 8466e69ffffffff
# 200
# Collected 246 tweets from 2021-05-01T20:42:04.000Z to 2021-04-27T00:07:38.000Z inside hexagon 8466e69ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e69ffffffff
# Searching tweets within hexagon 84660c5ffffffff :  37 out of 678 hexagons scanned for tweets!
# 200
# Collected 87 tweets from 2021-07-02T13:58:07.000Z to 2021-04-28T04:32:02.000Z inside hexagon 84660c5ffffffff
# Response returned no data
# No more data to collect for hexagon 84660c5ffffffff
# Searching tweets within hexagon 8466065ffffffff :  38 out of 678 hexagons scanned for tweets!
# 200
# Collected 62 tweets from 2021-07-03T01:01:35.000Z to 2021-04-28T19:46:32.000Z inside hexagon 8466065ffffffff
# Response returned no data
# No more data to collect for hexagon 8466065ffffffff
# Searching tweets within hexagon 8466c9bffffffff :  39 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466c9bffffffff
# Searching tweets within hexagon 8466c59ffffffff :  40 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 133 tweets from 2021-06-21T16:43:29.000Z to 2021-04-28T11:42:34.000Z inside hexagon 8466c59ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c59ffffffff
# Searching tweets within hexagon 8466c31ffffffff :  41 out of 678 hexagons scanned for tweets!
# 200
# Collected 4 tweets from 2021-06-10T14:27:34.000Z to 2021-05-26T21:54:41.000Z inside hexagon 8466c31ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c31ffffffff
# Searching tweets within hexagon 846655bffffffff :  42 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 846655bffffffff
# Searching tweets within hexagon 8466ec9ffffffff :  43 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 13 tweets from 2021-07-01T17:32:52.000Z to 2021-04-28T15:56:34.000Z inside hexagon 8466ec9ffffffff
# Response returned no data
# No more data to collect for hexagon 8466ec9ffffffff
# Searching tweets within hexagon 8466e85ffffffff :  44 out of 678 hexagons scanned for tweets!
# 200
# Collected 6 tweets from 2021-06-09T02:20:18.000Z to 2021-04-29T12:40:42.000Z inside hexagon 8466e85ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e85ffffffff
# Searching tweets within hexagon 848a485ffffffff :  45 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 848a485ffffffff
# Searching tweets within hexagon 8466ea5ffffffff :  46 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 4 tweets from 2021-05-13T13:20:08.000Z to 2021-04-28T18:41:30.000Z inside hexagon 8466ea5ffffffff
# Response returned no data
# No more data to collect for hexagon 8466ea5ffffffff
# Searching tweets within hexagon 8466f39ffffffff :  47 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 500 tweets from 2021-07-04T23:50:01.000Z to 2021-06-18T23:15:56.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 498 tweets from 2021-06-18T22:34:32.000Z to 2021-06-09T20:13:23.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 497 tweets from 2021-06-09T19:39:48.000Z to 2021-06-03T00:33:51.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 499 tweets from 2021-06-03T00:32:07.000Z to 2021-05-29T18:14:06.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 494 tweets from 2021-05-29T18:13:53.000Z to 2021-05-28T05:59:45.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 498 tweets from 2021-05-28T05:09:21.000Z to 2021-05-24T18:26:17.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 499 tweets from 2021-05-24T18:22:02.000Z to 2021-05-21T16:14:03.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 497 tweets from 2021-05-21T16:12:35.000Z to 2021-05-18T12:37:24.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 500 tweets from 2021-05-18T12:31:12.000Z to 2021-05-15T01:07:43.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 498 tweets from 2021-05-15T00:57:13.000Z to 2021-05-12T02:48:04.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 500 tweets from 2021-05-12T02:44:07.000Z to 2021-05-09T21:24:30.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 495 tweets from 2021-05-09T21:19:53.000Z to 2021-05-07T05:46:59.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 497 tweets from 2021-05-07T05:34:29.000Z to 2021-05-05T16:03:42.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 486 tweets from 2021-05-05T16:02:33.000Z to 2021-05-04T20:31:41.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 496 tweets from 2021-05-04T20:29:31.000Z to 2021-05-04T04:59:17.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 496 tweets from 2021-05-04T04:58:16.000Z to 2021-05-03T12:01:21.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 492 tweets from 2021-05-03T12:00:04.000Z to 2021-05-02T01:37:25.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 499 tweets from 2021-05-02T01:36:33.000Z to 2021-04-30T16:14:05.000Z inside hexagon 8466f39ffffffff
# 200
# Collected 368 tweets from 2021-04-30T16:13:17.000Z to 2021-04-27T00:25:57.000Z inside hexagon 8466f39ffffffff
# Response returned no data
# No more data to collect for hexagon 8466f39ffffffff
# Searching tweets within hexagon 84665c9ffffffff :  48 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 84665c9ffffffff
# Searching tweets within hexagon 8466c2dffffffff :  49 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 110 tweets from 2021-07-03T17:45:08.000Z to 2021-04-27T11:55:39.000Z inside hexagon 8466c2dffffffff
# Response returned no data
# No more data to collect for hexagon 8466c2dffffffff
# Searching tweets within hexagon 84660bdffffffff :  50 out of 678 hexagons scanned for tweets!
# 200
# Collected 240 tweets from 2021-07-02T02:40:50.000Z to 2021-04-27T00:13:57.000Z inside hexagon 84660bdffffffff
# Response returned no data
# No more data to collect for hexagon 84660bdffffffff
# Searching tweets within hexagon 84661e7ffffffff :  51 out of 678 hexagons scanned for tweets!
# 200
# Collected 8 tweets from 2021-07-02T21:00:11.000Z to 2021-05-04T13:50:31.000Z inside hexagon 84661e7ffffffff
# Response returned no data
# No more data to collect for hexagon 84661e7ffffffff
# Searching tweets within hexagon 8466eadffffffff :  52 out of 678 hexagons scanned for tweets!
# 200
# Collected 4 tweets from 2021-05-22T18:50:06.000Z to 2021-04-29T12:40:42.000Z inside hexagon 8466eadffffffff
# Response returned no data
# No more data to collect for hexagon 8466eadffffffff
# Searching tweets within hexagon 8466e25ffffffff :  53 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 499 tweets from 2021-07-04T23:04:59.000Z to 2021-06-22T03:44:48.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 498 tweets from 2021-06-22T03:37:45.000Z to 2021-06-11T22:11:00.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 499 tweets from 2021-06-11T21:47:08.000Z to 2021-06-05T23:19:22.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 493 tweets from 2021-06-05T23:12:43.000Z to 2021-05-30T20:12:12.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 495 tweets from 2021-05-30T19:53:43.000Z to 2021-05-28T15:32:56.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 495 tweets from 2021-05-28T15:26:18.000Z to 2021-05-24T18:26:15.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 497 tweets from 2021-05-24T18:22:34.000Z to 2021-05-20T03:17:19.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 490 tweets from 2021-05-20T03:13:03.000Z to 2021-05-16T13:55:42.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 495 tweets from 2021-05-16T13:51:28.000Z to 2021-05-13T03:52:43.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 487 tweets from 2021-05-13T03:45:49.000Z to 2021-05-11T02:03:33.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 494 tweets from 2021-05-11T01:44:50.000Z to 2021-05-09T20:56:41.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 500 tweets from 2021-05-09T20:56:05.000Z to 2021-05-07T15:27:32.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 497 tweets from 2021-05-07T15:14:13.000Z to 2021-05-05T23:45:36.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 493 tweets from 2021-05-05T23:39:00.000Z to 2021-05-05T05:04:18.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 493 tweets from 2021-05-05T05:04:02.000Z to 2021-05-04T14:25:20.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 494 tweets from 2021-05-04T14:24:02.000Z to 2021-05-04T03:12:47.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 492 tweets from 2021-05-04T03:11:46.000Z to 2021-05-03T05:00:45.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 494 tweets from 2021-05-03T04:59:34.000Z to 2021-05-02T03:39:54.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 495 tweets from 2021-05-02T03:34:01.000Z to 2021-05-01T02:34:51.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 498 tweets from 2021-05-01T02:33:55.000Z to 2021-04-29T00:40:14.000Z inside hexagon 8466e25ffffffff
# 200
# Collected 238 tweets from 2021-04-29T00:37:35.000Z to 2021-04-27T00:24:42.000Z inside hexagon 8466e25ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e25ffffffff
# Searching tweets within hexagon 846623bffffffff :  54 out of 678 hexagons scanned for tweets!
# 200
# Collected 371 tweets from 2021-07-04T23:36:52.000Z to 2021-05-28T02:28:02.000Z inside hexagon 846623bffffffff
# 200
# Collected 499 tweets from 2021-05-28T00:43:38.000Z to 2021-05-10T01:29:04.000Z inside hexagon 846623bffffffff
# 200
# Collected 495 tweets from 2021-05-10T00:05:54.000Z to 2021-05-03T00:31:46.000Z inside hexagon 846623bffffffff
# 200
# Collected 219 tweets from 2021-05-03T00:08:32.000Z to 2021-04-27T12:13:51.000Z inside hexagon 846623bffffffff
# Response returned no data
# No more data to collect for hexagon 846623bffffffff
# Searching tweets within hexagon 8466c07ffffffff :  55 out of 678 hexagons scanned for tweets!
# 200
# Collected 497 tweets from 2021-07-04T16:24:36.000Z to 2021-05-21T11:43:21.000Z inside hexagon 8466c07ffffffff
# 200
# Collected 499 tweets from 2021-05-21T03:18:09.000Z to 2021-05-06T12:07:58.000Z inside hexagon 8466c07ffffffff
# 200
# Collected 499 tweets from 2021-05-06T12:01:04.000Z to 2021-05-01T15:21:17.000Z inside hexagon 8466c07ffffffff
# 200
# Collected 166 tweets from 2021-05-01T14:36:41.000Z to 2021-04-27T11:55:39.000Z inside hexagon 8466c07ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c07ffffffff
# Searching tweets within hexagon 8466f3dffffffff :  56 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466f3dffffffff
# Searching tweets within hexagon 84661cbffffffff :  57 out of 678 hexagons scanned for tweets!
# 200
# Collected 86 tweets from 2021-06-30T18:52:49.000Z to 2021-04-28T15:03:28.000Z inside hexagon 84661cbffffffff
# Response returned no data
# No more data to collect for hexagon 84661cbffffffff
# Searching tweets within hexagon 848a6bbffffffff :  58 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a6bbffffffff
# Searching tweets within hexagon 8466437ffffffff :  59 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 7 tweets from 2021-06-27T14:22:24.000Z to 2021-05-05T06:01:29.000Z inside hexagon 8466437ffffffff
# Response returned no data
# No more data to collect for hexagon 8466437ffffffff
# Searching tweets within hexagon 8466717ffffffff :  60 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466717ffffffff
# Searching tweets within hexagon 848a4e5ffffffff :  61 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4e5ffffffff
# Searching tweets within hexagon 846656bffffffff :  62 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 80 tweets from 2021-06-27T16:18:14.000Z to 2021-04-28T16:09:35.000Z inside hexagon 846656bffffffff
# Response returned no data
# No more data to collect for hexagon 846656bffffffff
# Searching tweets within hexagon 846605bffffffff :  63 out of 678 hexagons scanned for tweets!
# 200
# Collected 186 tweets from 2021-07-03T03:17:23.000Z to 2021-04-27T03:42:52.000Z inside hexagon 846605bffffffff
# Response returned no data
# No more data to collect for hexagon 846605bffffffff
# Searching tweets within hexagon 848a419ffffffff :  64 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a419ffffffff
# Searching tweets within hexagon 8466513ffffffff :  65 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466513ffffffff
# Searching tweets within hexagon 8466c9dffffffff :  66 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466c9dffffffff
# Searching tweets within hexagon 8466c03ffffffff :  67 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 2 tweets from 2021-05-08T14:43:35.000Z to 2021-04-28T18:32:52.000Z inside hexagon 8466c03ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c03ffffffff
# Searching tweets within hexagon 84665abffffffff :  68 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 84665abffffffff
# Searching tweets within hexagon 8466f4bffffffff :  69 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 108 tweets from 2021-06-29T23:08:23.000Z to 2021-04-27T02:58:50.000Z inside hexagon 8466f4bffffffff
# Response returned no data
# No more data to collect for hexagon 8466f4bffffffff
# Searching tweets within hexagon 84661a1ffffffff :  70 out of 678 hexagons scanned for tweets!
# 200
# Collected 308 tweets from 2021-07-02T15:57:01.000Z to 2021-04-27T02:51:59.000Z inside hexagon 84661a1ffffffff
# Response returned no data
# No more data to collect for hexagon 84661a1ffffffff
# Searching tweets within hexagon 848a4d3ffffffff :  71 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4d3ffffffff
# Searching tweets within hexagon 8466c1bffffffff :  72 out of 678 hexagons scanned for tweets!
# 200
# Collected 12 tweets from 2021-06-23T02:50:24.000Z to 2021-04-30T02:42:02.000Z inside hexagon 8466c1bffffffff
# Response returned no data
# No more data to collect for hexagon 8466c1bffffffff
# Searching tweets within hexagon 8466715ffffffff :  73 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466715ffffffff
# Searching tweets within hexagon 8466e0dffffffff :  74 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 499 tweets from 2021-07-04T23:57:42.000Z to 2021-07-02T06:17:08.000Z inside hexagon 8466e0dffffffff
# 200
# Collected 500 tweets from 2021-07-02T05:49:21.000Z to 2021-06-30T18:28:56.000Z inside hexagon 8466e0dffffffff
# 200
# Collected 500 tweets from 2021-06-30T18:12:55.000Z to 2021-06-29T19:23:49.000Z inside hexagon 8466e0dffffffff
# 200
# Collected 500 tweets from 2021-06-29T19:10:55.000Z to 2021-06-28T13:35:14.000Z inside hexagon 8466e0dffffffff
# 200
# Collected
# Collected 499 tweets from 2021-06-01T18:52:48.000Z to 2021-05-17T20:08:10.000Z inside hexagon 846604dffffffff
# 200
# Collected 497 tweets from 2021-05-17T17:58:36.000Z to 2021-05-06T14:33:40.000Z inside hexagon 846604dffffffff
# 200
# Collected 498 tweets from 2021-05-06T14:31:39.000Z to 2021-05-04T10:45:41.000Z inside hexagon 846604dffffffff
# 200
# Collected 497 tweets from 2021-05-04T10:43:25.000Z to 2021-04-29T17:03:46.000Z inside hexagon 846604dffffffff
# 200
# Collected 104 tweets from 2021-04-29T16:45:31.000Z to 2021-04-27T00:01:27.000Z inside hexagon 846604dffffffff
# Response returned no data
# No more data to collect for hexagon 846604dffffffff
# Searching tweets within hexagon 84660d1ffffffff :  76 out of 678 hexagons scanned for tweets!
# 200
# Collected 500 tweets from 2021-07-04T17:40:13.000Z to 2021-05-31T23:37:46.000Z inside hexagon 84660d1ffffffff
# 200
# Collected 499 tweets from 2021-05-31T23:36:18.000Z to 2021-05-22T03:09:18.000Z inside hexagon 84660d1ffffffff
# 200
# Collected 500 tweets from 2021-05-22T00:34:17.000Z to 2021-05-09T02:33:59.000Z inside hexagon 84660d1ffffffff
# 200
# Collected 498 tweets from 2021-05-09T02:21:14.000Z to 2021-05-04T02:33:24.000Z inside hexagon 84660d1ffffffff
# 200
# Collected 425 tweets from 2021-05-04T02:33:04.000Z to 2021-04-27T01:16:48.000Z inside hexagon 84660d1ffffffff
# Response returned no data
# No more data to collect for hexagon 84660d1ffffffff
# Searching tweets within hexagon 8466c8bffffffff :  77 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466c8bffffffff
# Searching tweets within hexagon 8466ed5ffffffff :  78 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466ed5ffffffff
# Searching tweets within hexagon 8466c15ffffffff :  79 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 1 tweets from 2021-04-28T18:32:52.000Z to 2021-04-28T18:32:52.000Z inside hexagon 8466c15ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c15ffffffff
# Searching tweets within hexagon 8466e13ffffffff :  80 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 17 tweets from 2021-07-01T17:32:52.000Z to 2021-04-28T15:56:34.000Z inside hexagon 8466e13ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e13ffffffff
# Searching tweets within hexagon 8466c89ffffffff :  81 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466c89ffffffff
# Searching tweets within hexagon 8466023ffffffff :  82 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 90 tweets from 2021-06-16T13:54:53.000Z to 2021-04-28T15:12:33.000Z inside hexagon 8466023ffffffff
# Response returned no data
# No more data to collect for hexagon 8466023ffffffff
# Searching tweets within hexagon 8466e31ffffffff :  83 out of 678 hexagons scanned for tweets!
# 200
# Collected 498 tweets from 2021-07-04T15:43:53.000Z to 2021-05-17T11:18:59.000Z inside hexagon 8466e31ffffffff
# 200
# Collected 498 tweets from 2021-05-17T11:16:03.000Z to 2021-05-03T23:07:29.000Z inside hexagon 8466e31ffffffff
# 200
# Collected 205 tweets from 2021-05-03T22:55:40.000Z to 2021-04-27T03:47:35.000Z inside hexagon 8466e31ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e31ffffffff
# Searching tweets within hexagon 8466eb1ffffffff :  84 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8466eb1ffffffff
# Searching tweets within hexagon 8466447ffffffff :  85 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8466447ffffffff
# Searching tweets within hexagon 8467569ffffffff :  86 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 8467569ffffffff
# Searching tweets within hexagon 8466067ffffffff :  87 out of 678 hexagons scanned for tweets!
# 200
# Collected 490 tweets from 2021-07-03T17:05:44.000Z to 2021-05-06T16:21:05.000Z inside hexagon 8466067ffffffff
# 200
# Collected 470 tweets from 2021-05-06T16:16:31.000Z to 2021-04-27T01:16:22.000Z inside hexagon 8466067ffffffff
# Response returned no data
# No more data to collect for hexagon 8466067ffffffff
# Searching tweets within hexagon 84661d7ffffffff :  88 out of 678 hexagons scanned for tweets!
# 200
# Collected 207 tweets from 2021-07-04T01:41:18.000Z to 2021-06-02T01:55:05.000Z inside hexagon 84661d7ffffffff
# 200
# Collected 497 tweets from 2021-06-01T22:44:11.000Z to 2021-05-08T03:46:20.000Z inside hexagon 84661d7ffffffff
# 200
# Collected 497 tweets from 2021-05-08T02:47:50.000Z to 2021-05-01T01:01:52.000Z inside hexagon 84661d7ffffffff
# 200
# Collected 73 tweets from 2021-05-01T00:47:15.000Z to 2021-04-27T21:10:53.000Z inside hexagon 84661d7ffffffff
# Response returned no data
# No more data to collect for hexagon 84661d7ffffffff
# Searching tweets within hexagon 84662a7ffffffff :  89 out of 678 hexagons scanned for tweets!
# 200
# Collected 496 tweets from 2021-07-04T20:21:05.000Z to 2021-05-04T19:05:58.000Z inside hexagon 84662a7ffffffff
# 200
# Collected 197 tweets from 2021-05-04T19:00:51.000Z to 2021-04-27T03:14:45.000Z inside hexagon 84662a7ffffffff
# Response returned no data
# No more data to collect for hexagon 84662a7ffffffff
# Searching tweets within hexagon 8466425ffffffff :  90 out of 678 hexagons scanned for tweets!
# 200
# Collected 3 tweets from 2021-05-05T21:40:25.000Z to 2021-05-04T06:42:32.000Z inside hexagon 8466425ffffffff
# Response returned no data
# No more data to collect for hexagon 8466425ffffffff
# Searching tweets within hexagon 846756dffffffff :  91 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 846756dffffffff
# Searching tweets within hexagon 84665cbffffffff :  92 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Response returned no data
# No more data to collect for hexagon 84665cbffffffff
# ...
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 15 tweets from 2021-07-03T21:16:29.000Z to 2021-04-28T19:30:33.000Z inside hexagon 8467567ffffffff
# Response returned no data
# No more data to collect for hexagon 8467567ffffffff
# Searching tweets within hexagon 8466e05ffffffff :  664 out of 678 hexagons scanned for tweets!
# 200
# Collected 499 tweets from 2021-07-04T23:54:24.000Z to 2021-07-02T09:22:06.000Z inside hexagon 8466e05ffffffff
# 200
# Collected 500 tweets from 2021-07-02T06:50:30.000Z to 2021-06-30T18:28:56.000Z inside hexagon 8466e05ffffffff
# 200
# Collected
out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 23 tweets from 2021-07-02T13:28:36.000Z to 2021-04-28T15:51:24.000Z inside hexagon 84662a3ffffffff
# Response returned no data
# No more data to collect for hexagon 84662a3ffffffff
# Searching tweets within hexagon 8466c57ffffffff :  668 out of 678 hexagons scanned for tweets!
# 200
# Collected 24 tweets from 2021-06-12T01:22:39.000Z to 2021-04-28T14:59:05.000Z inside hexagon 8466c57ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c57ffffffff
# Searching tweets within hexagon 8466e2bffffffff :  669 out of 678 hexagons scanned for tweets!
# 200
# Collected 84 tweets from 2021-07-04T08:38:43.000Z to 2021-04-29T00:28:29.000Z inside hexagon 8466e2bffffffff
# Response returned no data
# No more data to collect for hexagon 8466e2bffffffff
# Searching tweets within hexagon 848a493ffffffff :  670 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a493ffffffff
# Searching tweets within hexagon 8466c93ffffffff :  671 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 1 tweets from 2021-05-13T01:56:16.000Z to 2021-05-13T01:56:16.000Z inside hexagon 8466c93ffffffff
# Response returned no data
# No more data to collect for hexagon 8466c93ffffffff
# Searching tweets within hexagon 8466e49ffffffff :  672 out of 678 hexagons scanned for tweets!
# 200
# Collected 500 tweets from 2021-07-04T23:03:58.000Z to 2021-05-14T17:43:17.000Z inside hexagon 8466e49ffffffff
# 200
# Collected 497 tweets from 2021-05-14T17:40:28.000Z to 2021-05-03T00:42:40.000Z inside hexagon 8466e49ffffffff
# 200
# Collected 188 tweets from 2021-05-03T00:34:27.000Z to 2021-04-27T01:12:03.000Z inside hexagon 8466e49ffffffff
# Response returned no data
# No more data to collect for hexagon 8466e49ffffffff
# Searching tweets within hexagon 848a4abffffffff :  673 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 848a4abffffffff
# Searching tweets within hexagon 84660e9ffffffff :  674 out of 678 hexagons scanned for tweets!
# 200
# Collected 64 tweets from 2021-07-02T13:58:07.000Z to 2021-04-28T04:32:02.000Z inside hexagon 84660e9ffffffff
# Response returned no data
# No more data to collect for hexagon 84660e9ffffffff
# Searching tweets within hexagon 8466433ffffffff :  675 out of 678 hexagons scanned for tweets!
# 200
# Collected 7 tweets from 2021-06-27T14:22:24.000Z to 2021-05-05T06:01:29.000Z inside hexagon 8466433ffffffff
# Response returned no data
# No more data to collect for hexagon 8466433ffffffff
# Searching tweets within hexagon 846642dffffffff :  676 out of 678 hexagons scanned for tweets!
# 429
# Too many requests, sleeping...
# Program restart!
# 200
# Collected 3 tweets from 2021-05-05T21:40:25.000Z to 2021-05-04T06:42:32.000Z inside hexagon 846642dffffffff
# Response returned no data
# No more data to collect for hexagon 846642dffffffff
# Searching tweets within hexagon 8467a53ffffffff :  677 out of 678 hexagons scanned for tweets!
# 200
# Response returned no data
# No more data to collect for hexagon 8467a53ffffffff
# Wall time: 2h 35min 27s

# %% [markdown]
# ### Loop through multiple cities test

# %%
import osmnx as ox
from shapely.geometry import box
import requests
import os
import json
import time
import datetime
import dateutil.parser

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
file_name_base = '../data/' #enter path where you want the file saved to

bearer_token = "AAAAAAAAAAAAAAAAAAAAAI1PNgEAAAAATarF1xcbxxXdqM15JyHfxL8TLqk%3DTbEmtm5q9UZ0rDTUQa0wUerv9w3LHZAX3UM9gn3qDNvFHhTB56"#os.environ.get("BEARER_TOKEN")

search_url = "https://api.twitter.com/2/tweets/search/all"

radius = "0.77mi" #"0.77mi" #2.15mi

res = 7 #https://github.com/uber/h3/blob/master/docs/core-library/restable.md


cities = ["Chicago", "New York City", "Houston", "Miami"]

for city in cities:
    # extract bounding box of each city
    city_AREA = gpd.GeoDataFrame(city_AREA, geometry=[box(*ox.gdf_from_place(city).bounds.values[0])])
    grid_city = create_hexgrid(city_AREA, hex_res = res, geometry_col='geometry', map_zoom=11, buffer=0.000,
                            stroke_weight=0.5, stroke_color='blue', plot=False)
    
    print(city, "has", str(len(grid_city)), "hexagons each with a radius of", radius)

    # iterate through each hexagon's centroid
    for index, row in grid_city.iterrows():
        # change point radius query for each area
        geo_query = f"{row.geometry.centroid.x} {row.geometry.centroid.y} {radius}"

        hex_id = row[f"hex_id_{res}"]
        print("Searching tweets within hexagon", hex_id, "of", city)
        # print(geo_query)
        # update query at each iteration
        query_params = {'query': f'(("george floyd" OR "tamir rice" OR "trayvon martin" OR "elijah mcclain" OR "breonna taylor" OR "breonna" OR "emmett till" OR "mike brown" OR "eric garner" OR "police brutality" OR "black lives matter" OR blacklivesmatter OR "police violence" OR blm OR racism OR "black lives" OR "police accountability" OR "police reform" OR "defund the police" OR "defund police" OR "abolish police" OR "abolish the police" OR "police abolition") OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #blacktranslivesmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter OR #justiceforbre)) has:geo point_radius:[{geo_query}]',
        #                 'tweet.fields': 'author_id,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,possibly_sensitive,public_metrics,referenced_tweets,reply_settings,source,text,withheld', point_radius:[-73.935242 40.730610 25mi] "tamir rice" OR "trayvon martin" OR "elijah mcclain" OR "breonna taylor" OR "emmett till" OR "mike brown" #emmettill
                        'tweet.fields': 'author_id,conversation_id,created_at,geo,entities,id,in_reply_to_user_id,referenced_tweets,public_metrics,text',
                        'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
                        'max_results': '500',
                        'expansions': 'geo.place_id,author_id,entities.mentions.username,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
                        'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
                        'start_time': '2020-05-20T00:00:00.00Z',
    #                     'end_time': '2020-05-27T00:00:00.00Z'}
                        'end_time': '2020-11-10T00:00:00.00Z'}


        def create_headers(bearer_token):
            headers = {"Authorization": "Bearer {}".format(bearer_token)}
            return headers


        def connect_to_endpoint(url, headers, params):
            response = requests.request("GET", search_url, headers=headers, params=params)
            print(response.status_code)
            if response.status_code != 200:
                raise Exception(response.status_code, response.text)
            return response.json()


        def main():
            headers = create_headers(bearer_token)
            json_response = connect_to_endpoint(search_url, headers, query_params)
    #         print(json.dumps(json_response, indent=4, sort_keys=True))

            try:
                ts = json_response['data'][-1]['created_at']
                stamp = dateutil.parser.parse(ts).strftime('%m%d%H%M%S_%y')
                # save one file for each response
                file_name = file_name_base + str(res) + 'res' + '/' + city + "_" + hex_id + "_" + str(res) + "res" + "_" + stamp + '.json'
    #             print(file_name)

                with open(file_name , 'w') as f:
    #                 json.dump(json_response['data'], f)
                    json.dump(json_response, f)

                print("Collected", len(json_response['data']), "tweets from", json_response['data'][0]['created_at'], 
                      "to", ts, "inside hexagon", hex_id)
                # update query with "next_token" from the most recent tweet to go to the next search page
                query_params['next_token'] = json_response['meta']['next_token']

            except KeyError:
                print("Response returned no data")

            return json_response


        if __name__ == "__main__":
            while(True):
                try:
                    response = main()  
                    if "next_token" not in response['meta']:
                        print("No more data to collect for hexagon", hex_id)
                        break
                except:
                    print("Too many requests, sleeping...")
                    time.sleep(20)
                    print("Program restart!")

# %%
# import requests
# import os
# import json
# import time
# import datetime
# import dateutil.parser

# # To set your environment variables in your terminal run the following line:
# # export 'BEARER_TOKEN'='<your_bearer_token>'
# file_name_base = '../data/' #enter path where you want the file saved to

# bearer_token = "AAAAAAAAAAAAAAAAAAAAAI1PNgEAAAAATarF1xcbxxXdqM15JyHfxL8TLqk%3DTbEmtm5q9UZ0rDTUQa0wUerv9w3LHZAX3UM9gn3qDNvFHhTB56"#os.environ.get("BEARER_TOKEN")

# search_url = "https://api.twitter.com/2/tweets/search/all"

# city = "test"

# # set search radius in miles
# radius = "0.76mi"
# # radius = "2mi"
# # iterate through each hexagon's centroid
# for index, row in hex_NYC.iterrows():
#     # print(row.geometry.centroid.x, row.geometry.centroid.y)

#     # change point radius query for each area
#     geo_query = f"{row.geometry.centroid.x} {row.geometry.centroid.y} {radius}"
    
#     hex_id = row[f"hex_id_{res}"]
#     print("Searching tweets within hexagon", hex_id)
#     # print(geo_query)
#     # update query at each iteration 
#     # f'("george floyd" OR "police brutality" OR "black lives matter" OR blacklivesmatter OR "police violence" OR blm OR racism OR "black lives" OR "police accountability" OR "police reform" OR "defund the police" OR "defund police" OR "abolish police" OR "abolish the police" OR "police abolition") OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #blacktranslivesmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter OR #justiceforbre) has:geo point_radius:[{geo_query}]',
#     query_params = {'query': f'(("george floyd" OR "police brutality" OR "black lives matter" OR blacklivesmatter OR "police violence" OR blm OR racism OR "black lives" OR "police accountability" OR "police reform" OR "defund the police" OR "defund police" OR "abolish police" OR "abolish the police" OR "police abolition") OR (#policereform OR #policeaccountability OR #defundthepolice OR #abolishthepolice OR #abolishpolice OR #defundpolice OR #criminaljusticereform OR #notoracism OR #blacklivesmatter OR #blm OR #georgefloyd OR #justiceforgeorgefloyd OR #icantbreathe OR #nojusticenopeace OR #justiceforfloyd OR #justiceforgeorge OR #sayhername OR #stopracismnow OR #endracism OR #blacklivesstillmatter OR #blacktranslivesmatter OR #taketheknee OR #breonnataylor OR #justiceforbreonnataylor OR #blackwomenmatter OR #justiceforbre)) has:geo point_radius:[{geo_query}]',
#     #                 'tweet.fields': 'author_id,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,possibly_sensitive,public_metrics,referenced_tweets,reply_settings,source,text,withheld', point_radius:[-73.935242 40.730610 25mi]
#                     'tweet.fields': 'author_id,conversation_id,created_at,geo,id,in_reply_to_user_id,referenced_tweets',
#                     'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
#                     'max_results': '500',
#                     'expansions': 'geo.place_id',
#     #                 'user.fields': 'created_at,description,id,location,name,protected,public_metrics,url,username,verified',
#                     'start_time': '2020-05-20T00:00:00.00Z',
# #                     'end_time': '2020-05-27T00:00:00.00Z'}
#                     'end_time': '2020-11-10T00:00:00.00Z'}


#     def create_headers(bearer_token):
#         headers = {"Authorization": "Bearer {}".format(bearer_token)}
#         return headers


#     def connect_to_endpoint(url, headers, params):
#         response = requests.request("GET", search_url, headers=headers, params=params)
#         print(response.status_code)
#         if response.status_code != 200:
#             raise Exception(response.status_code, response.text)
#         return response.json()


#     def main():
#         headers = create_headers(bearer_token)
#         json_response = connect_to_endpoint(search_url, headers, query_params)
# #         print(json.dumps(json_response, indent=4, sort_keys=True))
        
#         try:
#             ts = json_response['data'][-1]['created_at']
#             stamp = dateutil.parser.parse(ts).strftime('%m%d%H%M%S_%y')
#             # save one file for each response
#             file_name = file_name_base + city + "_" + hex_id + "_" + str(res) + "res" + "_" + stamp + '.json'
# #             print(file_name)

#             with open(file_name , 'w') as f:
# #                 json.dump(json_response['data'], f)
#                 json.dump(json_response, f)

#             print("Collected", len(json_response['data']), "tweets from", json_response['data'][0]['created_at'], 
#                   "to", ts, "inside hexagon", hex_id)
#             # update query with "next_token" from the most recent tweet to go to the next search page
#             query_params['next_token'] = json_response['meta']['next_token']
            
#         except KeyError:
#             print("Response returned no data")
        
#         return json_response

#     #     return json_response

# #     if __name__ == "__main__":
# #     #     test = main()
# #         main()


#     if __name__ == "__main__":
#         while(True):
#             try:
#                 response = main()  
#                 if "next_token" not in response['meta']:
#                     print("No more data to collect for hexagon", hex_id)
#                     break
#             except:
#                 print("Too many requests, sleeping...")
#                 time.sleep(20)
#                 print("Program restart!")
